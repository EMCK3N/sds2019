# %% [markdown]
# # Session 8
# ## Scraping 1 - Data Collection
# *Snorre Ralund *

# %% [markdown]
# ## Motivation
# <table><tr><td><img src='https://i.imgflip.com/2fg9un.jpg' style="width: 400px;"></td><td><img src='http://bigdataanalyticsnews.com/wp-content/uploads/2013/11/big-data.png' style="width: 400px;"></td></tr></table>

# %% [markdown]
# Getting information and data on a subject of interest is no longer reduced to *tedious* survey designs, and *expensive* collections, *time consuming* interviews and *standardized* register data.
#
# This session will teach you how to harvest some of the billions of data points being generated and shared on the internet everyday.
#
# ** Scraping skills allow you to: **
# - singlehandedly create powerful datasets.
# - Pose new questions that was very expensive or impossible with existing data sources.

# %% [markdown]
# ## Agenda
# **Collecting raw data** (*Tomorrow we shall focus on parsing and cleaning*)
#
# * The basics of webscraping
#     * Connecting, Crawling, Parsing,Storing, Logging.
# * Hands-on examples.
# * Ethical and Legal issues around scraping publicly available data.
# * Hacks: Backdoors, url construction and analyzing webpages.
# * Reliability of your data collection!

# %% [markdown]
# **Main take-aways**
# - Utilize the data sources around you. Combine them to reach new potentials.
# - Knowing how to build your own custom datasets from web sources, without having to spend a month manually curating the data.
# - Get to know some of the most valuable tricks,
# - And instructions on how to Handle with care.

# %% [markdown]
# <img src="https://i.imgflip.com/2fgdqb.jpg" title="made at imgflip.com"/></a>

# %% [markdown]
# ## Ethics / Legal Issues
# * If a regular user can’t access it, we shouldn’t try to get it (That is considered hacking)https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking.
# * Don't hit it to fast: Essentially a DENIAL OF SERVICE attack (DOS). [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb).
# * Add headers stating your name and email with your requests to ensure transparency.
# * Be careful with copyrighted material.
# * Fair use (don't take everything)
# * If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from.

# %% [markdown]
# <img src="https://github.com/snorreralund/images/raw/master/Sk%C3%A6rmbillede%202017-08-03%2014.46.32.png"/>

# %% [markdown]
# # quick 101

# %% [markdown]
# ![](overview_images/1.png)

# %% [markdown]
# ![](overview_images/2.png)

# %% [markdown]
# <img src=overview_images/2.png style="width:500px;" />
#
# To scrape information from the web is:
#
# 	    1. MAPPING: Finding URLs of the pages containing the information you want.
# 	    2. DOWNLOAD: Fetching the pages via HTTP.
# 	    3. PARSE: Extracting the information from HTML.
# 	    4. REPEAT: Finding more URL containing what you want, go back to 2.
#
# **Crawling** is when your collection spans unknown domains and is generally much harder.

# %% [markdown]
# ### Packages used
# Today we will mainly build on the python skills you have gotten so far, and tomorrow we will look into more specialized packages.
#
# * for connecting to the internet we use: **requests**
# * for parsing: **beautifulsoup** and **regex**
# * for automatic browsing / screen scraping (not covered in detail here): **selenium**
# * for behaving responsibly we use: **time** and ***our minds***
#
# We will write our scrapers with basic python, for larger projects consider looking into the packages **scrapy** or **pyspider**

# %%
import requests, re, time
from bs4 import BeautifulSoup

# %% [markdown]
# ## Connecting to the Internet

# %%
import requests
response = requests.get('https://www.google.com')
response.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="da"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2019/louisa-aldrich-blakes-154th-birthday-4903591901921280-l.png" itemprop="image"><meta content="Louisa Aldrich-Blakes 154 års fødselsdag" property="twitter:title"><meta content="Louisa Aldrich-Blakes 154 års fødselsdag #GoogleDoodle" property="twitter:description"><meta content="Louisa Aldrich-Blakes 154 års fødselsdag #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2019/louisa-aldrich-blakes-154th-birthday-4903591901921280-2x.jpg" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2019/louisa-aldrich-blakes-154th-birthday-4903591901921280-2x.jpg" property="og:image"><meta content="1000" property="og:image:width"><meta content="429" property="og:image:height"><title>Google</title><script nonce="0TBFTZGpAWyh30hsqOlbIg==">(function(){window.google={kEI:\'bUhVXYGKF9KKmwXw5ZfgDA\',kEXPI:\'0,1353747,57,1957,2423,1225,731,223,510,1065,2082,1069,379,206,397,620,53,932,499,32,671,10,262,75,5,371,338,2330394,329482,1294,12383,4855,32692,2074,13173,861,6063,6106,16521,369,3314,5505,2436,5373,575,1119,2,579,727,2431,1362,4323,4967,774,2256,4738,3122,6192,669,1050,1808,1478,7,491,10953,4604,693,2016,958,753,120,37,1180,1364,1611,2736,1558,1503,2,635,2399,837,44,2376,1772,635,3239,2884,20,318,1117,902,2128,1,369,1316,1461,519,400,992,509,776,8,85,24,2514,173,971,44,553,11,14,10,1269,390,1822,202,323,5,68,1177,7,842,322,193,1522,820,2620,335,483,260,52,1137,2,126,555,828,1160,1830,9,184,595,1182,520,360,1587,242,206,299,29,216,72,112,44,1023,4,75,328,1284,16,84,135,201,81,506,1590,268,62,1401,845,91,10,144,229,235,487,430,187,729,501,60,64,139,294,671,1515,908,133,501,272,87,173,773,515,40,111,373,7,504,224,94,498,523,76,164,811,1115,394,2,89,42,352,342,639,108,111,174,8,836,443,216,2,209,312,55,1002,14,1143,104,36,1034,320,443,412,631,310,219,5902835,2885,202,8797253,4,1572,882,444,1,2,31,49,1,900,583,9,304,1,8,1,2,2132,1,1,1,1,1,414,1,748,141,59,736,563,1,3159,41,9,17,26,7,163,20,23,29,4,2,20746484\',authuser:0,kscs:\'c9c918f0_bUhVXYGKF9KKmwXw5ZfgDA\',kGL:\'DK\',kBL:\'d31E\'};google.sn=\'webhp\';google.kHL=\'da\';google.jsfs=\'Ffpdje\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.time=function(){return(new Date).getTime()};google.log=function(a,b,e,c,g){if(a=google.logUrl(a,b,e,c,g)){b=new Image;var d=google.lc,f=google.li;d[f]=b;b.onerror=b.onload=b.onabort=function(){delete d[f]};google.vel&&google.vel.lu&&google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,e,c,g){var d="",f=google.ls||"";e||-1!=b.search("&ei=")||(d="&ei="+google.getEI(c),-1==b.search("&lei=")&&(c=google.getLEI(c))&&(d+="&lei="+c));c="";!e&&google.cshid&&-1==b.search("&cshid=")&&"slh"!=a&&(c="&cshid="+google.cshid);a=e||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+d+f+"&zx="+google.time()+c;/^http:/i.test(a)&&google.https()&&(google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};var a=window.location,b=a.href.indexOf("#");if(0<=b){var c=a.href.substring(b+1);/(^|&)q=/.test(c)&&-1==c.indexOf(" ...

# %% [markdown]
# **Connecting to the internet**
# **HTTP**
#
# *URL* : the adressline in our browser.
#
# Via HTTP we send a **get** request to an *address* with *instructions* ( - or rather our dns service provider redirects our request to the right address)
#
# *Address / Domain*: www.google.com
#
# *Instructions*: /trends?query=social+data+science
#
# *Header*: information send along with the request, including user agent (operating system, browser), cookies, and prefered encoding.
#
# *HTML*: HyperTextMarkupLanguage the language of displaying web content. More on this tomorrow.

# %% [markdown]
# ## Reliability and data quality issues: A first primer
# - You are in charge of the data quality!
#
# - **Everything** can go wrong.
#     - **Program** errors.
#     - Connection errors
#     - Domain wants to avoid scrapers and change the behavior of the site.
#     - Parsing errors.
#
# You will be graded based on your ability to document your data collection and your **critical** and **informed** inspection of data quality based on logs.

# %%
## SOLUTION

import requests,os,time
def ratelimit():
    "A function that handles the rate of your calls."
    time.sleep(1) # sleep one second.

class Connector():
  def __init__(self,logfile,overwrite_log=False,connector_type='requests',session=False,path2selenium='',n_tries = 5,timeout=30):
    """This Class implements a method for reliable connection to the internet and monitoring. 
    It handles simple errors due to connection problems, and logs a range of information for basic quality assessments
    
    Keyword arguments:
    logfile -- path to the logfile
    overwrite_log -- bool, defining if logfile should be cleared (rarely the case). 
    connector_type -- use the 'requests' module or the 'selenium'. Will have different since the selenium webdriver does not have a similar response object when using the get method, and monitoring the behavior cannot be automated in the same way.
    session -- requests.session object. For defining custom headers and proxies.
    path2selenium -- str, sets the path to the geckodriver needed when using selenium.
    n_tries -- int, defines the number of retries the *get* method will try to avoid random connection errors.
    timeout -- int, seconds the get request will wait for the server to respond, again to avoid connection errors.
    """
    
    ## Initialization function defining parameters. 
    self.n_tries = n_tries # For avoiding triviel error e.g. connection errors, this defines how many times it will retry.
    self.timeout = timeout # Defining the maximum time to wait for a server to response.
    ## not implemented here, if you use selenium.
    if connector_type=='selenium':
      assert path2selenium!='', "You need to specify the path to you geckodriver if you want to use Selenium"
      from selenium import webdriver 
      ## HIN download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases

      assert os.path.isfile(path2selenium),'You need to insert a valid path2selenium the path to your geckodriver. You can download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases'
      self.browser = webdriver.Firefox(executable_path=path2selenium) # start the browser with a path to the geckodriver.

    self.connector_type = connector_type # set the connector_type
    
    if session: # set the custom session
      self.session = session
    else:
      self.session = requests.session()
    self.logfilename = logfile # set the logfile path
    ## define header for the logfile
    header = ['id','project','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
    if os.path.isfile(logfile):        
      if overwrite_log==True:
        self.log = open(logfile,'w')
        self.log.write(';'.join(header))
      else:
        self.log = open(logfile,'a')
    else:
      self.log = open(logfile,'w')
      self.log.write(';'.join(header))
    ## load log 
    with open(logfile,'r') as f: # open file
        
      l = f.read().split('\n') # read and split file by newlines.
      ## set id
      if len(l)<=1:
        self.id = 0
      else:
        self.id = int(l[-1][0])+1
            
  def get(self,url,project_name):
    """Method for connector reliably to the internet, with multiple tries and simple error handling, as well as default logging function.
    Input url and the project name for the log (i.e. is it part of mapping the domain, or is it the part of the final stage in the data collection).
    
    Keyword arguments:
    url -- str, url
    project_name -- str, Name used for analyzing the log. Use case could be the 'Mapping of domain','Meta_data_collection','main data collection'. 
    """
     
    project_name = project_name.replace(';','-') # make sure the default csv seperator is not in the project_name.
    if self.connector_type=='requests': # Determine connector method.
      for _ in range(self.n_tries): # for loop defining number of retries with the requests method.
        ratelimit()
        t = time.time()
        try: # error handling 
          response = self.session.get(url,timeout = self.timeout) # make get call

          err = '' # define python error variable as empty assumming success.
          success = True # define success variable
          redirect_url = response.url # log current url, after potential redirects 
          dt = t - time.time() # define delta-time waiting for the server and downloading content.
          size = len(response.text) # define variable for size of html content of the response.
          response_code = response.status_code # log status code.
          ## log...
          call_id = self.id # get current unique identifier for the call
          self.id+=1 # increment call id
          #['id','project_name','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row to be written in the log.
          self.log.write('\n'+';'.join(map(str,row))) # write log.
          return response,call_id # return response and unique identifier.

        except Exception as e: # define error condition
          err = str(e) # python error
          response_code = '' # blank response code 
          success = False # call success = False
          size = 0 # content is empty.
          redirect_url = '' # redirect url empty 
          dt = t - time.time() # define delta t

          ## log...
          call_id = self.id # define unique identifier
          self.id+=1 # increment call_id

          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row
          self.log.write('\n'+';'.join(map(str,row))) # write row to log.
    else:
      t = time.time()
      ratelimit()
      self.browser.get(url) # use selenium get method
      ## log
      call_id = self.id # define unique identifier for the call. 
      self.id+=1 # increment the call_id
      err = '' # blank error message
      success = '' # success blank
      redirect_url = self.browser.current_url # redirect url.
      dt = t - time.time() # get time for get method ... NOTE: not necessarily the complete load time.
      size = len(self.browser.page_source) # get size of content ... NOTE: not necessarily correct, since selenium works in the background, and could still be loading.
      response_code = '' # empty response code.
      row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row 
      self.log.write('\n'+';'.join(map(str,row))) # write row to log file.
    # Using selenium it will not return a response object, instead you should call the browser object of the connector.
    ## connector.browser.page_source will give you the html.
      return call_id

# %%
### Here we define our connection to the internet
connector = Connector('logfile_sds_lecture8.csv')
## Test the get method. It takes a url, and name for the log. In this case test call. 
## Ideally you should name it after the project, and subpart of that project. 
## E.g. mapping_jobposting referring to the initial mapping of the domain.
response,call_id = connector.get('https://www.google.com','test_call')

import pandas as pd
pd.read_csv('logfile_sds_lecture8.csv', sep=';')
# Out:
#    id        project connector_type             t   delta_t  \
# 0   0      test_call       requests  1.565870e+09 -0.135661
# 1   1  google_trends       requests  1.565870e+09 -0.166464
# 2   0      test_call       requests  1.565870e+09 -0.136170
#
#                                                  url  \
# 0                             https://www.google.com
# 1  https://trends.google.com/trends/api/widgetdat...
# 2                             https://www.google.com
#
#                                         redirect_url  response_size  \
# 0                            https://www.google.com/          13328
# 1  https://trends.google.com/trends/api/widgetdat...           1632
# 2                            https://www.google.com/          13355
#
#    response_code  success  error
# 0            200     True    NaN
# 1            401     True    NaN
# 2            200     True    NaN

# %% [markdown]
# **Now** we are ready to get some data

# %% [markdown]
# ## **3 basic examples**
# ![](http://www.cluttercoach.net/wp/wp-content/uploads/2012/01/clapper-board-dreamstime_xs_22607452-300x300.jpg)

# %% [markdown]
# ### ** collecting data on display **
# ** static webpage example **
#
# visit the following website (https://www.basketball-reference.com/leagues/NBA_2018.html).
#
# The page displays tables of data that we want to collect.
# Tomorrow you will see how to parse such a table, but for now I want to show you a neat function that has already implemented this.

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2018.html' # link to the website
import pandas as pd 
dfs = pd.read_html(url) # parses all tables found on the page.

# %%
len(dfs)

dfs[0]
# Out:
#           Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0       Toronto Raptors* (1)  59  23  0.720     —  111.7  103.9  7.29
# 1        Boston Celtics* (2)  55  27  0.671   4.0  104.0  100.4  3.23
# 2    Philadelphia 76ers* (3)  52  30  0.634   7.0  109.8  105.3  4.30
# 3   Cleveland Cavaliers* (4)  50  32  0.610   9.0  110.9  109.9  0.59
# 4        Indiana Pacers* (5)  48  34  0.585  11.0  105.6  104.2  1.18
# 5            Miami Heat* (6)  44  38  0.537  15.0  103.4  102.9  0.15
# 6       Milwaukee Bucks* (7)  44  38  0.537  15.0  106.5  106.8 -0.45
# 7    Washington Wizards* (8)  43  39  0.524  16.0  106.6  106.0  0.53
# 8        Detroit Pistons (9)  39  43  0.476  20.0  103.8  103.9 -0.26
# 9     Charlotte Hornets (10)  36  46  0.439  23.0  108.2  108.0  0.07
# 10      New York Knicks (11)  29  53  0.354  30.0  104.5  108.0 -3.53
# 11        Brooklyn Nets (12)  28  54  0.341  31.0  106.6  110.3 -3.67
# 12        Chicago Bulls (13)  27  55  0.329  32.0  102.9  110.0 -6.84
# 13        Orlando Magic (14)  25  57  0.305  34.0  103.4  108.2 -4.92
# 14        Atlanta Hawks (15)  24  58  0.293  35.0  103.4  108.8 -5.30

# %%
EC_df = pd.read_html(url,attrs={'id':'confs_standings_E'}) # only parse the tables with attribute confs_standings_E

# %% [markdown]
# ### ** collecting data behind the display**
# ** dynamic webpage example **
#
# Websites that continually show new data (jobsites, real-estate pages, social media), are as a rule dynamic webpages, where the whole page is not send as raw HTML. Instead a set of instructions (JavaScripts) on how to build it is send. Within those instructions we can often find direct calls to the data displayed.
#
# Click on the following link: https://trends.google.com/trends/explore?date=all&geo=DK&q=H%C3%A5ndbold,Fodbold
#
# Here we want to collect the data behind the graph. Open your browsers **>Network Monitor<** tool and search for the request that contains the data.

# %%
import requests
url = 'https://trends.google.dk/trends/api/widgetdata/multiline?hl=da&tz=-120&req=%7B%22time%22:%222004-01-01+2019-08-15%22,%22resolution%22:%22MONTH%22,%22locale%22:%22da%22,%22comparisonItem%22:%5B%7B%22geo%22:%7B%22country%22:%22US%22%7D,%22complexKeywordsRestriction%22:%7B%22keyword%22:%5B%7B%22type%22:%22BROAD%22,%22value%22:%22NBA%22%7D%5D%7D%7D,%7B%22geo%22:%7B%22country%22:%22US%22%7D,%22complexKeywordsRestriction%22:%7B%22keyword%22:%5B%7B%22type%22:%22BROAD%22,%22value%22:%22NFL%22%7D%5D%7D%7D%5D,%22requestOptions%22:%7B%22property%22:%22%22,%22backend%22:%22IZG%22,%22category%22:0%7D%7D&token=APP6_UEAAAAAXVah1s5ksgx_5PkVjQQ-mdfoFB66br0s&tz=-120'
response,call_id = connector.get(url,'google_trends')
raw_json = response.text.split(',', maxsplit = 1)[1]
import json
data = json.loads(raw_json)
data
# Out:
# {'default': {'averages': [21, 28],
#   'timelineData': [{'formattedAxisTime': '1. jan. 2004',
#     'formattedTime': 'jan. 2004',
#     'formattedValue': ['9', '20'],
#     'hasData': [True, True],
#     'time': '1072915200',
#     'value': [9, 20]},
#    {'formattedAxisTime': '1. feb. 2004',
#     'formattedTime': 'feb. 2004',
#     'formattedValue': ['11', '14'],
#     'hasData': [True, True],
#     'time': '1075593600',
#     'value': [11, 14]},
#    {'formattedAxisTime': '1. mar. 2004',
#     'formattedTime': 'mar. 2004',
#     'formattedValue': ['8', '11'],
#     'hasData': [True, True],
#     'time': '1078099200',
#     'value': [8, 11]},
#    {'formattedAxisTime': '1. apr. 2004',
#     'formattedTime': 'apr. 2004',
#     'formattedValue': ['12', '15'],
#     'hasData': [True, True],
#     'time': '1080777600',
#     'value': [12, 15]},
#    {'formattedAxisTime': '1. maj 2004',
#     'formattedTime': 'maj 2004',
#     'formattedValue': ['13', '6'],
#     'hasData': [True, True],
#     'time': '1083369600',
#     'value': [13, 6]},
#    {'formattedAxisTime': '1. jun. 2004',
#     'formattedTime': 'jun. 2004',
#     'formattedValue': ['16', '5'],
#     'hasData': [True, True],
#     'time': '1086048000',
#     'value': [16, 5]},
#    {'formattedAxisTime': '1. jul. 2004',
#     'formattedTime': 'jul. 2004',
#     'formattedValue': ['8', '7'],
#     'hasData': [True, True],
#     'time': '1088640000',
#     'value': [8, 7]},
#    {'formattedAxisTime': '1. aug. 2004',
#     'formattedTime': 'aug. 2004',
#     'formattedValue': ['5', '14'],
#     'hasData': [True, True],
#     'time': '1091318400',
#     'value': [5, 14]},
#    {'formattedAxisTime': '1. sep. 2004',
#     'formattedTime': 'sep. 2004',
#     'formattedValue': ['5', '24'],
#     'hasData': [True, True],
#     'time': '1093996800',
#     'value': [5, 24]},
#    {'formattedAxisTime': '1. okt. 2004',
#     'formattedTime': 'okt. 2004',
#     'formattedValue': ['8', '19'],
#     'hasData': [True, True],
#     'time': '1096588800',
#     'value': [8, 19]},
#    {'formattedAxisTime': '1. nov. 2004',
#     'formattedTime': 'nov. 2004',
#     'formattedValue': ['12', '19'],
#     'hasData': [True, True],
#     'time': '1099267200',
#     'value': [12, 19]},
#    {'formattedAxisTime': '1. dec. 2004',
#     'formattedTime': 'dec. 2004',
#     'formattedValue': ['9', '21'],
#     'hasData': [True, True],
#     'time': '1101859200',
#     'value': [9, 21]},
#    {'formattedAxisTime': '1. jan. 2005',
#     'formattedTime': 'jan. 2005',
#     'formattedValue': ['8', '23'],
#     'hasData': [True, True],
#     'time': '1104537600',
#     'value': [8, 23]},
#    {'formattedAxisTime': '1. feb. 2005',
#     'formattedTime': 'feb. 2005',
#     'formattedValue': ['12', '14'],
#     'hasData': [True, True],
#     'time': '1107216000',
#     'value': [12, 14]},
#    {'formattedAxisTime': '1. mar. 2005',
#     'formattedTime': 'mar. 2005',
#     'formattedValue': ['9', '11'],
#     'hasData': [True, True],
#     'time': '1109635200',
#     'value': [9, 11]},
#    {'formattedAxisTime': '1. apr. 2005',
#     'formattedTime': 'apr. 2005',
#     'formattedValue': ['12', '16'],
#     'hasData': [True, True],
#     'time': '1112313600',
#     'value': [12, 16]},
#    {'formattedAxisTime': '1. maj 2005',
#     'formattedTime': 'maj 2005',
#     'formattedValue': ['13', '6'],
#     'hasData': [True, True],
#     'time': '1114905600',
#     'value': [13, 6]},
#    {'formattedAxisTime': '1. jun. 2005',
#     'formattedTime': 'jun. 2005',
#     'formattedValue': ['17', '5'],
#     'hasData': [True, True],
#     'time': '1117584000',
#     'value': [17, 5]},
#    {'formattedAxisTime': '1. jul. 2005',
#     'formattedTime': 'jul. 2005',
#     'formattedValue': ['8', '6'],
#     'hasData': [True, True],
#     'time': '1120176000',
#     'value': [8, 6]},
#    {'formattedAxisTime': '1. aug. 2005',
#     'formattedTime': 'aug. 2005',
#     'formattedValue': ['5', '15'],
#     'hasData': [True, True],
#     'time': '1122854400',
#     'value': [5, 15]},
#    {'formattedAxisTime': '1. sep. 2005',
#     'formattedTime': 'sep. 2005',
#     'formattedValue': ['5', '26'],
#     'hasData': [True, True],
#     'time': '1125532800',
#     'value': [5, 26]},
#    {'formattedAxisTime': '1. okt. 2005',
#     'formattedTime': 'okt. 2005',
#     'formattedValue': ['7', '23'],
#     'hasData': [True, True],
#     'time': '1128124800',
#     'value': [7, 23]},
#    {'formattedAxisTime': '1. nov. 2005',
#     'formattedTime': 'nov. 2005',
#     'formattedValue': ['10', '24'],
#     'hasData': [True, True],
#     'time': '1130803200',
#     'value': [10, 24]},
#    {'formattedAxisTime': '1. dec. 2005',
#     'formattedTime': 'dec. 2005',
#     'formattedValue': ['9', '25'],
#     'hasData': [True, True],
#     'time': '1133395200',
#     'value': [9, 25]},
#    {'formattedAxisTime': '1. jan. 2006',
#     'formattedTime': 'jan. 2006',
#     'formattedValue': ['10', '29'],
#     'hasData': [True, True],
#     'time': '1136073600',
#     'value': [10, 29]},
#    {'formattedAxisTime': '1. feb. 2006',
#     'formattedTime': 'feb. 2006',
#     'formattedValue': ['11', '14'],
#     'hasData': [True, True],
#     'time': '1138752000',
#     'value': [11, 14]},
#    {'formattedAxisTime': '1. mar. 2006',
#     'formattedTime': 'mar. 2006',
#     'formattedValue': ['9', '14'],
#     'hasData': [True, True],
#     'time': '1141171200',
#     'value': [9, 14]},
#    {'formattedAxisTime': '1. apr. 2006',
#     'formattedTime': 'apr. 2006',
#     'formattedValue': ['12', '19'],
#     'hasData': [True, True],
#     'time': '1143849600',
#     'value': [12, 19]},
#    {'formattedAxisTime': '1. maj 2006',
#     'formattedTime': 'maj 2006',
#     'formattedValue': ['15', '9'],
#     'hasData': [True, True],
#     'time': '1146441600',
#     'value': [15, 9]},
#    {'formattedAxisTime': '1. jun. 2006',
#     'formattedTime': 'jun. 2006',
#     'formattedValue': ['17', '6'],
#     'hasData': [True, True],
#     'time': '1149120000',
#     'value': [17, 6]},
#    {'formattedAxisTime': '1. jul. 2006',
#     'formattedTime': 'jul. 2006',
#     'formattedValue': ['8', '8'],
#     'hasData': [True, True],
#     'time': '1151712000',
#     'value': [8, 8]},
#    {'formattedAxisTime': '1. aug. 2006',
#     'formattedTime': 'aug. 2006',
#     'formattedValue': ['4', '17'],
#     'hasData': [True, True],
#     'time': '1154390400',
#     'value': [4, 17]},
#    {'formattedAxisTime': '1. sep. 2006',
#     'formattedTime': 'sep. 2006',
#     'formattedValue': ['5', '30'],
#     'hasData': [True, True],
#     'time': '1157068800',
#     'value': [5, 30]},
#    {'formattedAxisTime': '1. okt. 2006',
#     'formattedTime': 'okt. 2006',
#     'formattedValue': ['7', '26'],
#     'hasData': [True, True],
#     'time': '1159660800',
#     'value': [7, 26]},
#    {'formattedAxisTime': '1. nov. 2006',
#     'formattedTime': 'nov. 2006',
#     'formattedValue': ['9', '25'],
#     'hasData': [True, True],
#     'time': '1162339200',
#     'value': [9, 25]},
#    {'formattedAxisTime': '1. dec. 2006',
#     'formattedTime': 'dec. 2006',
#     'formattedValue': ['11', '30'],
#     'hasData': [True, True],
#     'time': '1164931200',
#     'value': [11, 30]},
#    {'formattedAxisTime': '1. jan. 2007',
#     'formattedTime': 'jan. 2007',
#     'formattedValue': ['10', '29'],
#     'hasData': [True, True],
#     'time': '1167609600',
#     'value': [10, 29]},
#    {'formattedAxisTime': '1. feb. 2007',
#     'formattedTime': 'feb. 2007',
#     'formattedValue': ['12', '15'],
#     'hasData': [True, True],
#     'time': '1170288000',
#     'value': [12, 15]},
#    {'formattedAxisTime': '1. mar. 2007',
#     'formattedTime': 'mar. 2007',
#     'formattedValue': ['9', '12'],
#     'hasData': [True, True],
#     'time': '1172707200',
#     'value': [9, 12]},
#    {'formattedAxisTime': '1. apr. 2007',
#     'formattedTime': 'apr. 2007',
#     'formattedValue': ['13', '18'],
#     'hasData': [True, True],
#     'time': '1175385600',
#     'value': [13, 18]},
#    {'formattedAxisTime': '1. maj 2007',
#     'formattedTime': 'maj 2007',
#     'formattedValue': ['16', '8'],
#     'hasData': [True, True],
#     'time': '1177977600',
#     'value': [16, 8]},
#    {'formattedAxisTime': '1. jun. 2007',
#     'formattedTime': 'jun. 2007',
#     'formattedValue': ['16', '6'],
#     'hasData': [True, True],
#     'time': '1180656000',
#     'value': [16, 6]},
#    {'formattedAxisTime': '1. jul. 2007',
#     'formattedTime': 'jul. 2007',
#     'formattedValue': ['8', '7'],
#     'hasData': [True, True],
#     'time': '1183248000',
#     'value': [8, 7]},
#    {'formattedAxisTime': '1. aug. 2007',
#     'formattedTime': 'aug. 2007',
#     'formattedValue': ['5', '17'],
#     'hasData': [True, True],
#     'time': '1185926400',
#     'value': [5, 17]},
#    {'formattedAxisTime': '1. sep. 2007',
#     'formattedTime': 'sep. 2007',
#     'formattedValue': ['4', '33'],
#     'hasData': [True, True],
#     'time': '1188604800',
#     'value': [4, 33]},
#    {'formattedAxisTime': '1. okt. 2007',
#     'formattedTime': 'okt. 2007',
#     'formattedValue': ['7', '27'],
#     'hasData': [True, True],
#     'time': '1191196800',
#     'value': [7, 27]},
#    {'formattedAxisTime': '1. nov. 2007',
#     'formattedTime': 'nov. 2007',
#     'formattedValue': ['9', '31'],
#     'hasData': [True, True],
#     'time': '1193875200',
#     'value': [9, 31]},
#    {'formattedAxisTime': '1. dec. 2007',
#     'formattedTime': 'dec. 2007',
#     'formattedValue': ['9', '35'],
#     'hasData': [True, True],
#     'time': '1196467200',
#     'value': [9, 35]},
#    {'formattedAxisTime': '1. jan. 2008',
#     'formattedTime': 'jan. 2008',
#     'formattedValue': ['9', '28'],
#     'hasData': [True, True],
#     'time': '1199145600',
#     'value': [9, 28]},
#    {'formattedAxisTime': '1. feb. 2008',
#     'formattedTime': 'feb. 2008',
#     'formattedValue': ['13', '15'],
#     'hasData': [True, True],
#     'time': '1201824000',
#     'value': [13, 15]},
#    {'formattedAxisTime': '1. mar. 2008',
#     'formattedTime': 'mar. 2008',
#     'formattedValue': ['11', '11'],
#     'hasData': [True, True],
#     'time': '1204329600',
#     'value': [11, 11]},
#    {'formattedAxisTime': '1. apr. 2008',
#     'formattedTime': 'apr. 2008',
#     'formattedValue': ['15', '16'],
#     'hasData': [True, True],
#     'time': '1207008000',
#     'value': [15, 16]},
#    {'formattedAxisTime': '1. maj 2008',
#     'formattedTime': 'maj 2008',
#     'formattedValue': ['18', '6'],
#     'hasData': [True, True],
#     'time': '1209600000',
#     'value': [18, 6]},
#    {'formattedAxisTime': '1. jun. 2008',
#     'formattedTime': 'jun. 2008',
#     'formattedValue': ['18', '5'],
#     'hasData': [True, True],
#     'time': '1212278400',
#     'value': [18, 5]},
#    {'formattedAxisTime': '1. jul. 2008',
#     'formattedTime': 'jul. 2008',
#     'formattedValue': ['7', '7'],
#     'hasData': [True, True],
#     'time': '1214870400',
#     'value': [7, 7]},
#    {'formattedAxisTime': '1. aug. 2008',
#     'formattedTime': 'aug. 2008',
#     'formattedValue': ['5', '16'],
#     'hasData': [True, True],
#     'time': '1217548800',
#     'value': [5, 16]},
#    {'formattedAxisTime': '1. sep. 2008',
#     'formattedTime': 'sep. 2008',
#     'formattedValue': ['4', '32'],
#     'hasData': [True, True],
#     'time': '1220227200',
#     'value': [4, 32]},
#    {'formattedAxisTime': '1. okt. 2008',
#     'formattedTime': 'okt. 2008',
#     'formattedValue': ['8', '25'],
#     'hasData': [True, True],
#     'time': '1222819200',
#     'value': [8, 25]},
#    {'formattedAxisTime': '1. nov. 2008',
#     'formattedTime': 'nov. 2008',
#     'formattedValue': ['10', '29'],
#     'hasData': [True, True],
#     'time': '1225497600',
#     'value': [10, 29]},
#    {'formattedAxisTime': '1. dec. 2008',
#     'formattedTime': 'dec. 2008',
#     'formattedValue': ['10', '33'],
#     'hasData': [True, True],
#     'time': '1228089600',
#     'value': [10, 33]},
#    {'formattedAxisTime': '1. jan. 2009',
#     'formattedTime': 'jan. 2009',
#     'formattedValue': ['10', '26'],
#     'hasData': [True, True],
#     'time': '1230768000',
#     'value': [10, 26]},
#    {'formattedAxisTime': '1. feb. 2009',
#     'formattedTime': 'feb. 2009',
#     'formattedValue': ['14', '14'],
#     'hasData': [True, True],
#     'time': '1233446400',
#     'value': [14, 14]},
#    {'formattedAxisTime': '1. mar. 2009',
#     'formattedTime': 'mar. 2009',
#     'formattedValue': ['10', '12'],
#     'hasData': [True, True],
#     'time': '1235865600',
#     'value': [10, 12]},
#    {'formattedAxisTime': '1. apr. 2009',
#     'formattedTime': 'apr. 2009',
#     'formattedValue': ['14', '17'],
#     'hasData': [True, True],
#     'time': '1238544000',
#     'value': [14, 17]},
#    {'formattedAxisTime': '1. maj 2009',
#     'formattedTime': 'maj 2009',
#     'formattedValue': ['20', '6'],
#     'hasData': [True, True],
#     'time': '1241136000',
#     'value': [20, 6]},
#    {'formattedAxisTime': '1. jun. 2009',
#     'formattedTime': 'jun. 2009',
#     'formattedValue': ['18', '5'],
#     'hasData': [True, True],
#     'time': '1243814400',
#     'value': [18, 5]},
#    {'formattedAxisTime': '1. jul. 2009',
#     'formattedTime': 'jul. 2009',
#     'formattedValue': ['8', '6'],
#     'hasData': [True, True],
#     'time': '1246406400',
#     'value': [8, 6]},
#    {'formattedAxisTime': '1. aug. 2009',
#     'formattedTime': 'aug. 2009',
#     'formattedValue': ['5', '16'],
#     'hasData': [True, True],
#     'time': '1249084800',
#     'value': [5, 16]},
#    {'formattedAxisTime': '1. sep. 2009',
#     'formattedTime': 'sep. 2009',
#     'formattedValue': ['5', '32'],
#     'hasData': [True, True],
#     'time': '1251763200',
#     'value': [5, 32]},
#    {'formattedAxisTime': '1. okt. 2009',
#     'formattedTime': 'okt. 2009',
#     'formattedValue': ['8', '29'],
#     'hasData': [True, True],
#     'time': '1254355200',
#     'value': [8, 29]},
#    {'formattedAxisTime': '1. nov. 2009',
#     'formattedTime': 'nov. 2009',
#     'formattedValue': ['10', '31'],
#     'hasData': [True, True],
#     'time': '1257033600',
#     'value': [10, 31]},
#    {'formattedAxisTime': '1. dec. 2009',
#     'formattedTime': 'dec. 2009',
#     'formattedValue': ['10', '34'],
#     'hasData': [True, True],
#     'time': '1259625600',
#     'value': [10, 34]},
#    {'formattedAxisTime': '1. jan. 2010',
#     'formattedTime': 'jan. 2010',
#     'formattedValue': ['11', '33'],
#     'hasData': [True, True],
#     'time': '1262304000',
#     'value': [11, 33]},
#    {'formattedAxisTime': '1. feb. 2010',
#     'formattedTime': 'feb. 2010',
#     'formattedValue': ['14', '12'],
#     'hasData': [True, True],
#     'time': '1264982400',
#     'value': [14, 12]},
#    {'formattedAxisTime': '1. mar. 2010',
#     'formattedTime': 'mar. 2010',
#     'formattedValue': ['10', '11'],
#     'hasData': [True, True],
#     'time': '1267401600',
#     'value': [10, 11]},
#    {'formattedAxisTime': '1. apr. 2010',
#     'formattedTime': 'apr. 2010',
#     'formattedValue': ['15', '22'],
#     'hasData': [True, True],
#     'time': '1270080000',
#     'value': [15, 22]},
#    {'formattedAxisTime': '1. maj 2010',
#     'formattedTime': 'maj 2010',
#     'formattedValue': ['19', '6'],
#     'hasData': [True, True],
#     'time': '1272672000',
#     'value': [19, 6]},
#    {'formattedAxisTime': '1. jun. 2010',
#     'formattedTime': 'jun. 2010',
#     'formattedValue': ['22', '5'],
#     'hasData': [True, True],
#     'time': '1275350400',
#     'value': [22, 5]},
#    {'formattedAxisTime': '1. jul. 2010',
#     'formattedTime': 'jul. 2010',
#     'formattedValue': ['14', '7'],
#     'hasData': [True, True],
#     'time': '1277942400',
#     'value': [14, 7]},
#    {'formattedAxisTime': '1. aug. 2010',
#     'formattedTime': 'aug. 2010',
#     'formattedValue': ['7', '18'],
#     'hasData': [True, True],
#     'time': '1280620800',
#     'value': [7, 18]},
#    {'formattedAxisTime': '1. sep. 2010',
#     'formattedTime': 'sep. 2010',
#     'formattedValue': ['6', '37'],
#     'hasData': [True, True],
#     'time': '1283299200',
#     'value': [6, 37]},
#    {'formattedAxisTime': '1. okt. 2010',
#     'formattedTime': 'okt. 2010',
#     'formattedValue': ['12', '34'],
#     'hasData': [True, True],
#     'time': '1285891200',
#     'value': [12, 34]},
#    {'formattedAxisTime': '1. nov. 2010',
#     'formattedTime': 'nov. 2010',
#     'formattedValue': ['13', '36'],
#     'hasData': [True, True],
#     'time': '1288569600',
#     'value': [13, 36]},
#    {'formattedAxisTime': '1. dec. 2010',
#     'formattedTime': 'dec. 2010',
#     'formattedValue': ['14', '37'],
#     'hasData': [True, True],
#     'time': '1291161600',
#     'value': [14, 37]},
#    {'axisNote': {'text': 'Der blev foretaget en forbedring af vores geografiske tildeling fra den 1. januar 2011.'},
#     'formattedAxisTime': '1. jan. 2011',
#     'formattedTime': 'jan. 2011',
#     'formattedValue': ['16', '46'],
#     'hasData': [True, True],
#     'time': '1293840000',
#     'value': [16, 46]},
#    {'formattedAxisTime': '1. feb. 2011',
#     'formattedTime': 'feb. 2011',
#     'formattedValue': ['23', '16'],
#     'hasData': [True, True],
#     'time': '1296518400',
#     'value': [23, 16]},
#    {'formattedAxisTime': '1. mar. 2011',
#     'formattedTime': 'mar. 2011',
#     'formattedValue': ['17', '11'],
#     'hasData': [True, True],
#     'time': '1298937600',
#     'value': [17, 11]},
#    {'formattedAxisTime': '1. apr. 2011',
#     'formattedTime': 'apr. 2011',
#     'formattedValue': ['26', '20'],
#     'hasData': [True, True],
#     'time': '1301616000',
#     'value': [26, 20]},
#    {'formattedAxisTime': '1. maj 2011',
#     'formattedTime': 'maj 2011',
#     'formattedValue': ['32', '9'],
#     'hasData': [True, True],
#     'time': '1304208000',
#     'value': [32, 9]},
#    {'formattedAxisTime': '1. jun. 2011',
#     'formattedTime': 'jun. 2011',
#     'formattedValue': ['29', '7'],
#     'hasData': [True, True],
#     'time': '1306886400',
#     'value': [29, 7]},
#    {'formattedAxisTime': '1. jul. 2011',
#     'formattedTime': 'jul. 2011',
#     'formattedValue': ['7', '14'],
#     'hasData': [True, True],
#     'time': '1309478400',
#     'value': [7, 14]},
#    {'formattedAxisTime': '1. aug. 2011',
#     'formattedTime': 'aug. 2011',
#     'formattedValue': ['5', '26'],
#     'hasData': [True, True],
#     'time': '1312156800',
#     'value': [5, 26]},
#    {'formattedAxisTime': '1. sep. 2011',
#     'formattedTime': 'sep. 2011',
#     'formattedValue': ['5', '47'],
#     'hasData': [True, True],
#     'time': '1314835200',
#     'value': [5, 47]},
#    {'formattedAxisTime': '1. okt. 2011',
#     'formattedTime': 'okt. 2011',
#     'formattedValue': ['9', '43'],
#     'hasData': [True, True],
#     'time': '1317427200',
#     'value': [9, 43]},
#    {'formattedAxisTime': '1. nov. 2011',
#     'formattedTime': 'nov. 2011',
#     'formattedValue': ['10', '45'],
#     'hasData': [True, True],
#     'time': '1320105600',
#     'value': [10, 45]},
#    {'formattedAxisTime': '1. dec. 2011',
#     'formattedTime': 'dec. 2011',
#     'formattedValue': ['20', '47'],
#     'hasData': [True, True],
#     'time': '1322697600',
#     'value': [20, 47]},
#    {'formattedAxisTime': '1. jan. 2012',
#     'formattedTime': 'jan. 2012',
#     'formattedValue': ['19', '52'],
#     'hasData': [True, True],
#     'time': '1325376000',
#     'value': [19, 52]},
#    {'formattedAxisTime': '1. feb. 2012',
#     'formattedTime': 'feb. 2012',
#     'formattedValue': ['26', '17'],
#     'hasData': [True, True],
#     'time': '1328054400',
#     'value': [26, 17]},
#    {'formattedAxisTime': '1. mar. 2012',
#     'formattedTime': 'mar. 2012',
#     'formattedValue': ['23', '17'],
#     'hasData': [True, True],
#     'time': '1330560000',
#     'value': [23, 17]},
#    {'formattedAxisTime': '1. apr. 2012',
#     'formattedTime': 'apr. 2012',
#     'formattedValue': ['25', '29'],
#     'hasData': [True, True],
#     'time': '1333238400',
#     'value': [25, 29]},
#    {'formattedAxisTime': '1. maj 2012',
#     'formattedTime': 'maj 2012',
#     'formattedValue': ['36', '9'],
#     'hasData': [True, True],
#     'time': '1335830400',
#     'value': [36, 9]},
#    {'formattedAxisTime': '1. jun. 2012',
#     'formattedTime': 'jun. 2012',
#     'formattedValue': ['43', '7'],
#     'hasData': [True, True],
#     'time': '1338508800',
#     'value': [43, 7]},
#    {'formattedAxisTime': '1. jul. 2012',
#     'formattedTime': 'jul. 2012',
#     'formattedValue': ['17', '9'],
#     'hasData': [True, True],
#     'time': '1341100800',
#     'value': [17, 9]},
#    {'formattedAxisTime': '1. aug. 2012',
#     'formattedTime': 'aug. 2012',
#     'formattedValue': ['9', '25'],
#     'hasData': [True, True],
#     'time': '1343779200',
#     'value': [9, 25]},
#    {'formattedAxisTime': '1. sep. 2012',
#     'formattedTime': 'sep. 2012',
#     'formattedValue': ['7', '59'],
#     'hasData': [True, True],
#     'time': '1346457600',
#     'value': [7, 59]},
#    {'formattedAxisTime': '1. okt. 2012',
#     'formattedTime': 'okt. 2012',
#     'formattedValue': ['13', '47'],
#     'hasData': [True, True],
#     'time': '1349049600',
#     'value': [13, 47]},
#    {'formattedAxisTime': '1. nov. 2012',
#     'formattedTime': 'nov. 2012',
#     'formattedValue': ['19', '46'],
#     'hasData': [True, True],
#     'time': '1351728000',
#     'value': [19, 46]},
#    {'formattedAxisTime': '1. dec. 2012',
#     'formattedTime': 'dec. 2012',
#     'formattedValue': ['20', '56'],
#     'hasData': [True, True],
#     'time': '1354320000',
#     'value': [20, 56]},
#    {'formattedAxisTime': '1. jan. 2013',
#     'formattedTime': 'jan. 2013',
#     'formattedValue': ['21', '46'],
#     'hasData': [True, True],
#     'time': '1356998400',
#     'value': [21, 46]},
#    {'formattedAxisTime': '1. feb. 2013',
#     'formattedTime': 'feb. 2013',
#     'formattedValue': ['25', '18'],
#     'hasData': [True, True],
#     'time': '1359676800',
#     'value': [25, 18]},
#    {'formattedAxisTime': '1. mar. 2013',
#     'formattedTime': 'mar. 2013',
#     'formattedValue': ['24', '16'],
#     'hasData': [True, True],
#     'time': '1362096000',
#     'value': [24, 16]},
#    {'formattedAxisTime': '1. apr. 2013',
#     'formattedTime': 'apr. 2013',
#     'formattedValue': ['29', '28'],
#     'hasData': [True, True],
#     'time': '1364774400',
#     'value': [29, 28]},
#    {'formattedAxisTime': '1. maj 2013',
#     'formattedTime': 'maj 2013',
#     'formattedValue': ['37', '9'],
#     'hasData': [True, True],
#     'time': '1367366400',
#     'value': [37, 9]},
#    {'formattedAxisTime': '1. jun. 2013',
#     'formattedTime': 'jun. 2013',
#     'formattedValue': ['46', '8'],
#     'hasData': [True, True],
#     'time': '1370044800',
#     'value': [46, 8]},
#    {'formattedAxisTime': '1. jul. 2013',
#     'formattedTime': 'jul. 2013',
#     'formattedValue': ['15', '10'],
#     'hasData': [True, True],
#     'time': '1372636800',
#     'value': [15, 10]},
#    {'formattedAxisTime': '1. aug. 2013',
#     'formattedTime': 'aug. 2013',
#     'formattedValue': ['8', '28'],
#     'hasData': [True, True],
#     'time': '1375315200',
#     'value': [8, 28]},
#    {'formattedAxisTime': '1. sep. 2013',
#     'formattedTime': 'sep. 2013',
#     'formattedValue': ['7', '64'],
#     'hasData': [True, True],
#     'time': '1377993600',
#     'value': [7, 64]},
#    {'formattedAxisTime': '1. okt. 2013',
#     'formattedTime': 'okt. 2013',
#     'formattedValue': ['13', '54'],
#     'hasData': [True, True],
#     'time': '1380585600',
#     'value': [13, 54]},
#    {'formattedAxisTime': '1. nov. 2013',
#     'formattedTime': 'nov. 2013',
#     'formattedValue': ['20', '52'],
#     'hasData': [True, True],
#     'time': '1383264000',
#     'value': [20, 52]},
#    {'formattedAxisTime': '1. dec. 2013',
#     'formattedTime': 'dec. 2013',
#     'formattedValue': ['20', '58'],
#     'hasData': [True, True],
#     'time': '1385856000',
#     'value': [20, 58]},
#    {'formattedAxisTime': '1. jan. 2014',
#     'formattedTime': 'jan. 2014',
#     'formattedValue': ['20', '52'],
#     'hasData': [True, True],
#     'time': '1388534400',
#     'value': [20, 52]},
#    {'formattedAxisTime': '1. feb. 2014',
#     'formattedTime': 'feb. 2014',
#     'formattedValue': ['23', '18'],
#     'hasData': [True, True],
#     'time': '1391212800',
#     'value': [23, 18]},
#    {'formattedAxisTime': '1. mar. 2014',
#     'formattedTime': 'mar. 2014',
#     'formattedValue': ['20', '15'],
#     'hasData': [True, True],
#     'time': '1393632000',
#     'value': [20, 15]},
#    {'formattedAxisTime': '1. apr. 2014',
#     'formattedTime': 'apr. 2014',
#     'formattedValue': ['32', '14'],
#     'hasData': [True, True],
#     'time': '1396310400',
#     'value': [32, 14]},
#    {'formattedAxisTime': '1. maj 2014',
#     'formattedTime': 'maj 2014',
#     'formattedValue': ['42', '29'],
#     'hasData': [True, True],
#     'time': '1398902400',
#     'value': [42, 29]},
#    {'formattedAxisTime': '1. jun. 2014',
#     'formattedTime': 'jun. 2014',
#     'formattedValue': ['36', '7'],
#     'hasData': [True, True],
#     'time': '1401580800',
#     'value': [36, 7]},
#    {'formattedAxisTime': '1. jul. 2014',
#     'formattedTime': 'jul. 2014',
#     'formattedValue': ['18', '10'],
#     'hasData': [True, True],
#     'time': '1404172800',
#     'value': [18, 10]},
#    {'formattedAxisTime': '1. aug. 2014',
#     'formattedTime': 'aug. 2014',
#     'formattedValue': ['9', '28'],
#     'hasData': [True, True],
#     'time': '1406851200',
#     'value': [9, 28]},
#    {'formattedAxisTime': '1. sep. 2014',
#     'formattedTime': 'sep. 2014',
#     'formattedValue': ['7', '64'],
#     'hasData': [True, True],
#     'time': '1409529600',
#     'value': [7, 64]},
#    {'formattedAxisTime': '1. okt. 2014',
#     'formattedTime': 'okt. 2014',
#     'formattedValue': ['15', '55'],
#     'hasData': [True, True],
#     'time': '1412121600',
#     'value': [15, 55]},
#    {'formattedAxisTime': '1. nov. 2014',
#     'formattedTime': 'nov. 2014',
#     'formattedValue': ['20', '59'],
#     'hasData': [True, True],
#     'time': '1414800000',
#     'value': [20, 59]},
#    {'formattedAxisTime': '1. dec. 2014',
#     'formattedTime': 'dec. 2014',
#     'formattedValue': ['22', '64'],
#     'hasData': [True, True],
#     'time': '1417392000',
#     'value': [22, 64]},
#    {'formattedAxisTime': '1. jan. 2015',
#     'formattedTime': 'jan. 2015',
#     'formattedValue': ['22', '57'],
#     'hasData': [True, True],
#     'time': '1420070400',
#     'value': [22, 57]},
#    {'formattedAxisTime': '1. feb. 2015',
#     'formattedTime': 'feb. 2015',
#     'formattedValue': ['24', '18'],
#     'hasData': [True, True],
#     'time': '1422748800',
#     'value': [24, 18]},
#    {'formattedAxisTime': '1. mar. 2015',
#     'formattedTime': 'mar. 2015',
#     'formattedValue': ['21', '16'],
#     'hasData': [True, True],
#     'time': '1425168000',
#     'value': [21, 16]},
#    {'formattedAxisTime': '1. apr. 2015',
#     'formattedTime': 'apr. 2015',
#     'formattedValue': ['34', '17'],
#     'hasData': [True, True],
#     'time': '1427846400',
#     'value': [34, 17]},
#    {'formattedAxisTime': '1. maj 2015',
#     'formattedTime': 'maj 2015',
#     'formattedValue': ['42', '20'],
#     'hasData': [True, True],
#     'time': '1430438400',
#     'value': [42, 20]},
#    {'formattedAxisTime': '1. jun. 2015',
#     'formattedTime': 'jun. 2015',
#     'formattedValue': ['48', '7'],
#     'hasData': [True, True],
#     'time': '1433116800',
#     'value': [48, 7]},
#    {'formattedAxisTime': '1. jul. 2015',
#     'formattedTime': 'jul. 2015',
#     'formattedValue': ['15', '10'],
#     'hasData': [True, True],
#     'time': '1435708800',
#     'value': [15, 10]},
#    {'formattedAxisTime': '1. aug. 2015',
#     'formattedTime': 'aug. 2015',
#     'formattedValue': ['8', '29'],
#     'hasData': [True, True],
#     'time': '1438387200',
#     'value': [8, 29]},
#    {'formattedAxisTime': '1. sep. 2015',
#     'formattedTime': 'sep. 2015',
#     'formattedValue': ['9', '70'],
#     'hasData': [True, True],
#     'time': '1441065600',
#     'value': [9, 70]},
#    {'formattedAxisTime': '1. okt. 2015',
#     'formattedTime': 'okt. 2015',
#     'formattedValue': ['14', '63'],
#     'hasData': [True, True],
#     'time': '1443657600',
#     'value': [14, 63]},
#    {'formattedAxisTime': '1. nov. 2015',
#     'formattedTime': 'nov. 2015',
#     'formattedValue': ['24', '72'],
#     'hasData': [True, True],
#     'time': '1446336000',
#     'value': [24, 72]},
#    {'formattedAxisTime': '1. dec. 2015',
#     'formattedTime': 'dec. 2015',
#     'formattedValue': ['26', '65'],
#     'hasData': [True, True],
#     'time': '1448928000',
#     'value': [26, 65]},
#    {'axisNote': {'text': 'Der blev foretaget en forbedring af vores dataindsamlingssystem fra den 01.01.2016.'},
#     'formattedAxisTime': '1. jan. 2016',
#     'formattedTime': 'jan. 2016',
#     'formattedValue': ['29', '84'],
#     'hasData': [True, True],
#     'time': '1451606400',
#     'value': [29, 84]},
#    {'formattedAxisTime': '1. feb. 2016',
#     'formattedTime': 'feb. 2016',
#     'formattedValue': ['33', '21'],
#     'hasData': [True, True],
#     'time': '1454284800',
#     'value': [33, 21]},
#    {'formattedAxisTime': '1. mar. 2016',
#     'formattedTime': 'mar. 2016',
#     'formattedValue': ['29', '15'],
#     'hasData': [True, True],
#     'time': '1456790400',
#     'value': [29, 15]},
#    {'formattedAxisTime': '1. apr. 2016',
#     'formattedTime': 'apr. 2016',
#     'formattedValue': ['47', '29'],
#     'hasData': [True, True],
#     'time': '1459468800',
#     'value': [47, 29]},
#    {'formattedAxisTime': '1. maj 2016',
#     'formattedTime': 'maj 2016',
#     'formattedValue': ['65', '11'],
#     'hasData': [True, True],
#     'time': '1462060800',
#     'value': [65, 11]},
#    {'formattedAxisTime': '1. jun. 2016',
#     'formattedTime': 'jun. 2016',
#     'formattedValue': ['73', '8'],
#     'hasData': [True, True],
#     'time': '1464739200',
#     'value': [73, 8]},
#    {'formattedAxisTime': '1. jul. 2016',
#     'formattedTime': 'jul. 2016',
#     'formattedValue': ['22', '10'],
#     'hasData': [True, True],
#     'time': '1467331200',
#     'value': [22, 10]},
#    {'formattedAxisTime': '1. aug. 2016',
#     'formattedTime': 'aug. 2016',
#     'formattedValue': ['10', '26'],
#     'hasData': [True, True],
#     'time': '1470009600',
#     'value': [10, 26]},
#    {'formattedAxisTime': '1. sep. 2016',
#     'formattedTime': 'sep. 2016',
#     'formattedValue': ['11', '73'],
#     'hasData': [True, True],
#     'time': '1472688000',
#     'value': [11, 73]},
#    {'formattedAxisTime': '1. okt. 2016',
#     'formattedTime': 'okt. 2016',
#     'formattedValue': ['18', '73'],
#     'hasData': [True, True],
#     'time': '1475280000',
#     'value': [18, 73]},
#    {'formattedAxisTime': '1. nov. 2016',
#     'formattedTime': 'nov. 2016',
#     'formattedValue': ['29', '68'],
#     'hasData': [True, True],
#     'time': '1477958400',
#     'value': [29, 68]},
#    {'formattedAxisTime': '1. dec. 2016',
#     'formattedTime': 'dec. 2016',
#     'formattedValue': ['77', '80'],
#     'hasData': [True, True],
#     'time': '1480550400',
#     'value': [77, 80]},
#    {'formattedAxisTime': '1. jan. 2017',
#     'formattedTime': 'jan. 2017',
#     'formattedValue': ['32', '81'],
#     'hasData': [True, True],
#     'time': '1483228800',
#     'value': [32, 81]},
#    {'formattedAxisTime': '1. feb. 2017',
#     'formattedTime': 'feb. 2017',
#     'formattedValue': ['38', '19'],
#     'hasData': [True, True],
#     'time': '1485907200',
#     'value': [38, 19]},
#    {'formattedAxisTime': '1. mar. 2017',
#     'formattedTime': 'mar. 2017',
#     'formattedValue': ['34', '17'],
#     'hasData': [True, True],
#     'time': '1488326400',
#     'value': [34, 17]},
#    {'formattedAxisTime': '1. apr. 2017',
#     'formattedTime': 'apr. 2017',
#     'formattedValue': ['57', '32'],
#     'hasData': [True, True],
#     'time': '1491004800',
#     'value': [57, 32]},
#    {'formattedAxisTime': '1. maj 2017',
#     'formattedTime': 'maj 2017',
#     'formattedValue': ['62', '10'],
#     'hasData': [True, True],
#     'time': '1493596800',
#     'value': [62, 10]},
#    {'formattedAxisTime': '1. jun. 2017',
#     'formattedTime': 'jun. 2017',
#     'formattedValue': ['72', '8'],
#     'hasData': [True, True],
#     'time': '1496275200',
#     'value': [72, 8]},
#    {'formattedAxisTime': '1. jul. 2017',
#     'formattedTime': 'jul. 2017',
#     'formattedValue': ['23', '9'],
#     'hasData': [True, True],
#     'time': '1498867200',
#     'value': [23, 9]},
#    {'formattedAxisTime': '1. aug. 2017',
#     'formattedTime': 'aug. 2017',
#     'formattedValue': ['14', '29'],
#     'hasData': [True, True],
#     'time': '1501545600',
#     'value': [14, 29]},
#    {'formattedAxisTime': '1. sep. 2017',
#     'formattedTime': 'sep. 2017',
#     'formattedValue': ['15', '79'],
#     'hasData': [True, True],
#     'time': '1504224000',
#     'value': [15, 79]},
#    {'formattedAxisTime': '1. okt. 2017',
#     'formattedTime': 'okt. 2017',
#     'formattedValue': ['30', '79'],
#     'hasData': [True, True],
#     'time': '1506816000',
#     'value': [30, 79]},
#    {'formattedAxisTime': '1. nov. 2017',
#     'formattedTime': 'nov. 2017',
#     'formattedValue': ['38', '68'],
#     'hasData': [True, True],
#     'time': '1509494400',
#     'value': [38, 68]},
#    {'formattedAxisTime': '1. dec. 2017',
#     'formattedTime': 'dec. 2017',
#     'formattedValue': ['38', '80'],
#     'hasData': [True, True],
#     'time': '1512086400',
#     'value': [38, 80]},
#    {'formattedAxisTime': '1. jan. 2018',
#     'formattedTime': 'jan. 2018',
#     'formattedValue': ['41', '78'],
#     'hasData': [True, True],
#     'time': '1514764800',
#     'value': [41, 78]},
#    {'formattedAxisTime': '1. feb. 2018',
#     'formattedTime': 'feb. 2018',
#     'formattedValue': ['44', '19'],
#     'hasData': [True, True],
#     'time': '1517443200',
#     'value': [44, 19]},
#    {'formattedAxisTime': '1. mar. 2018',
#     'formattedTime': 'mar. 2018',
#     'formattedValue': ['39', '19'],
#     'hasData': [True, True],
#     'time': '1519862400',
#     'value': [39, 19]},
#    {'formattedAxisTime': '1. apr. 2018',
#     'formattedTime': 'apr. 2018',
#     'formattedValue': ['73', '34'],
#     'hasData': [True, True],
#     'time': '1522540800',
#     'value': [73, 34]},
#    {'formattedAxisTime': '1. maj 2018',
#     'formattedTime': 'maj 2018',
#     'formattedValue': ['90', '10'],
#     'hasData': [True, True],
#     'time': '1525132800',
#     'value': [90, 10]},
#    {'formattedAxisTime': '1. jun. 2018',
#     'formattedTime': 'jun. 2018',
#     'formattedValue': ['58', '8'],
#     'hasData': [True, True],
#     'time': '1527811200',
#     'value': [58, 8]},
#    {'formattedAxisTime': '1. jul. 2018',
#     'formattedTime': 'jul. 2018',
#     'formattedValue': ['24', '10'],
#     'hasData': [True, True],
#     'time': '1530403200',
#     'value': [24, 10]},
#    {'formattedAxisTime': '1. aug. 2018',
#     'formattedTime': 'aug. 2018',
#     'formattedValue': ['12', '31'],
#     'hasData': [True, True],
#     'time': '1533081600',
#     'value': [12, 31]},
#    {'formattedAxisTime': '1. sep. 2018',
#     'formattedTime': 'sep. 2018',
#     'formattedValue': ['13', '89'],
#     'hasData': [True, True],
#     'time': '1535760000',
#     'value': [13, 89]},
#    {'formattedAxisTime': '1. okt. 2018',
#     'formattedTime': 'okt. 2018',
#     'formattedValue': ['33', '79'],
#     'hasData': [True, True],
#     'time': '1538352000',
#     'value': [33, 79]},
#    {'formattedAxisTime': '1. nov. 2018',
#     'formattedTime': 'nov. 2018',
#     'formattedValue': ['42', '78'],
#     'hasData': [True, True],
#     'time': '1541030400',
#     'value': [42, 78]},
#    {'formattedAxisTime': '1. dec. 2018',
#     'formattedTime': 'dec. 2018',
#     'formattedValue': ['43', '100'],
#     'hasData': [True, True],
#     'time': '1543622400',
#     'value': [43, 100]},
#    {'formattedAxisTime': '1. jan. 2019',
#     'formattedTime': 'jan. 2019',
#     'formattedValue': ['44', '90'],
#     'hasData': [True, True],
#     'time': '1546300800',
#     'value': [44, 90]},
#    {'formattedAxisTime': '1. feb. 2019',
#     'formattedTime': 'feb. 2019',
#     'formattedValue': ['47', '20'],
#     'hasData': [True, True],
#     'time': '1548979200',
#     'value': [47, 20]},
#    {'formattedAxisTime': '1. mar. 2019',
#     'formattedTime': 'mar. 2019',
#     'formattedValue': ['42', '19'],
#     'hasData': [True, True],
#     'time': '1551398400',
#     'value': [42, 19]},
#    {'formattedAxisTime': '1. apr. 2019',
#     'formattedTime': 'apr. 2019',
#     'formattedValue': ['70', '32'],
#     'hasData': [True, True],
#     'time': '1554076800',
#     'value': [70, 32]},
#    {'formattedAxisTime': '1. maj 2019',
#     'formattedTime': 'maj 2019',
#     'formattedValue': ['87', '8'],
#     'hasData': [True, True],
#     'time': '1556668800',
#     'value': [87, 8]},
#    {'formattedAxisTime': '1. jun. 2019',
#     'formattedTime': 'jun. 2019',
#     'formattedValue': ['71', '7'],
#     'hasData': [True, True],
#     'time': '1559347200',
#     'value': [71, 7]},
#    {'formattedAxisTime': '1. jul. 2019',
#     'formattedTime': 'jul. 2019',
#     'formattedValue': ['25', '10'],
#     'hasData': [True, True],
#     'time': '1561939200',
#     'value': [25, 10]},
#    {'formattedAxisTime': '1. aug. 2019',
#     'formattedTime': 'aug. 2019',
#     'formattedValue': ['12', '31'],
#     'hasData': [True, True],
#     'isPartial': True,
#     'time': '1564617600',
#     'value': [12, 31]}]}}

# %%
pd.DataFrame(data['default']['timelineData'])
# Out:
#     axisNote formattedAxisTime formattedTime formattedValue       hasData  \
# 0        NaN      1. jan. 2004     jan. 2004        [9, 20]  [True, True]
# 1        NaN      1. feb. 2004     feb. 2004       [11, 14]  [True, True]
# 2        NaN      1. mar. 2004     mar. 2004        [8, 11]  [True, True]
# 3        NaN      1. apr. 2004     apr. 2004       [12, 15]  [True, True]
# 4        NaN       1. maj 2004      maj 2004        [13, 6]  [True, True]
# 5        NaN      1. jun. 2004     jun. 2004        [16, 5]  [True, True]
# 6        NaN      1. jul. 2004     jul. 2004         [8, 7]  [True, True]
# 7        NaN      1. aug. 2004     aug. 2004        [5, 14]  [True, True]
# 8        NaN      1. sep. 2004     sep. 2004        [5, 24]  [True, True]
# 9        NaN      1. okt. 2004     okt. 2004        [8, 19]  [True, True]
# 10       NaN      1. nov. 2004     nov. 2004       [12, 19]  [True, True]
# 11       NaN      1. dec. 2004     dec. 2004        [9, 21]  [True, True]
# 12       NaN      1. jan. 2005     jan. 2005        [8, 23]  [True, True]
# 13       NaN      1. feb. 2005     feb. 2005       [12, 14]  [True, True]
# 14       NaN      1. mar. 2005     mar. 2005        [9, 11]  [True, True]
# 15       NaN      1. apr. 2005     apr. 2005       [12, 16]  [True, True]
# 16       NaN       1. maj 2005      maj 2005        [13, 6]  [True, True]
# 17       NaN      1. jun. 2005     jun. 2005        [17, 5]  [True, True]
# 18       NaN      1. jul. 2005     jul. 2005         [8, 6]  [True, True]
# 19       NaN      1. aug. 2005     aug. 2005        [5, 15]  [True, True]
# 20       NaN      1. sep. 2005     sep. 2005        [5, 26]  [True, True]
# 21       NaN      1. okt. 2005     okt. 2005        [7, 23]  [True, True]
# 22       NaN      1. nov. 2005     nov. 2005       [10, 24]  [True, True]
# 23       NaN      1. dec. 2005     dec. 2005        [9, 25]  [True, True]
# 24       NaN      1. jan. 2006     jan. 2006       [10, 29]  [True, True]
# 25       NaN      1. feb. 2006     feb. 2006       [11, 14]  [True, True]
# 26       NaN      1. mar. 2006     mar. 2006        [9, 14]  [True, True]
# 27       NaN      1. apr. 2006     apr. 2006       [12, 19]  [True, True]
# 28       NaN       1. maj 2006      maj 2006        [15, 9]  [True, True]
# 29       NaN      1. jun. 2006     jun. 2006        [17, 6]  [True, True]
# ..       ...               ...           ...            ...           ...
# 158      NaN      1. mar. 2017     mar. 2017       [34, 17]  [True, True]
# 159      NaN      1. apr. 2017     apr. 2017       [57, 32]  [True, True]
# 160      NaN       1. maj 2017      maj 2017       [62, 10]  [True, True]
# 161      NaN      1. jun. 2017     jun. 2017        [72, 8]  [True, True]
# 162      NaN      1. jul. 2017     jul. 2017        [23, 9]  [True, True]
# 163      NaN      1. aug. 2017     aug. 2017       [14, 29]  [True, True]
# 164      NaN      1. sep. 2017     sep. 2017       [15, 79]  [True, True]
# 165      NaN      1. okt. 2017     okt. 2017       [30, 79]  [True, True]
# 166      NaN      1. nov. 2017     nov. 2017       [38, 68]  [True, True]
# 167      NaN      1. dec. 2017     dec. 2017       [38, 80]  [True, True]
# 168      NaN      1. jan. 2018     jan. 2018       [41, 78]  [True, True]
# 169      NaN      1. feb. 2018     feb. 2018       [44, 19]  [True, True]
# 170      NaN      1. mar. 2018     mar. 2018       [39, 19]  [True, True]
# 171      NaN      1. apr. 2018     apr. 2018       [73, 34]  [True, True]
# 172      NaN       1. maj 2018      maj 2018       [90, 10]  [True, True]
# 173      NaN      1. jun. 2018     jun. 2018        [58, 8]  [True, True]
# 174      NaN      1. jul. 2018     jul. 2018       [24, 10]  [True, True]
# 175      NaN      1. aug. 2018     aug. 2018       [12, 31]  [True, True]
# 176      NaN      1. sep. 2018     sep. 2018       [13, 89]  [True, True]
# 177      NaN      1. okt. 2018     okt. 2018       [33, 79]  [True, True]
# 178      NaN      1. nov. 2018     nov. 2018       [42, 78]  [True, True]
# 179      NaN      1. dec. 2018     dec. 2018      [43, 100]  [True, True]
# 180      NaN      1. jan. 2019     jan. 2019       [44, 90]  [True, True]
# 181      NaN      1. feb. 2019     feb. 2019       [47, 20]  [True, True]
# 182      NaN      1. mar. 2019     mar. 2019       [42, 19]  [True, True]
# 183      NaN      1. apr. 2019     apr. 2019       [70, 32]  [True, True]
# 184      NaN       1. maj 2019      maj 2019        [87, 8]  [True, True]
# 185      NaN      1. jun. 2019     jun. 2019        [71, 7]  [True, True]
# 186      NaN      1. jul. 2019     jul. 2019       [25, 10]  [True, True]
# 187      NaN      1. aug. 2019     aug. 2019       [12, 31]  [True, True]
#
#     isPartial        time      value
# 0         NaN  1072915200    [9, 20]
# 1         NaN  1075593600   [11, 14]
# 2         NaN  1078099200    [8, 11]
# 3         NaN  1080777600   [12, 15]
# 4         NaN  1083369600    [13, 6]
# 5         NaN  1086048000    [16, 5]
# 6         NaN  1088640000     [8, 7]
# 7         NaN  1091318400    [5, 14]
# 8         NaN  1093996800    [5, 24]
# 9         NaN  1096588800    [8, 19]
# 10        NaN  1099267200   [12, 19]
# 11        NaN  1101859200    [9, 21]
# 12        NaN  1104537600    [8, 23]
# 13        NaN  1107216000   [12, 14]
# 14        NaN  1109635200    [9, 11]
# 15        NaN  1112313600   [12, 16]
# 16        NaN  1114905600    [13, 6]
# 17        NaN  1117584000    [17, 5]
# 18        NaN  1120176000     [8, 6]
# 19        NaN  1122854400    [5, 15]
# 20        NaN  1125532800    [5, 26]
# 21        NaN  1128124800    [7, 23]
# 22        NaN  1130803200   [10, 24]
# 23        NaN  1133395200    [9, 25]
# 24        NaN  1136073600   [10, 29]
# 25        NaN  1138752000   [11, 14]
# 26        NaN  1141171200    [9, 14]
# 27        NaN  1143849600   [12, 19]
# 28        NaN  1146441600    [15, 9]
# 29        NaN  1149120000    [17, 6]
# ..        ...         ...        ...
# 158       NaN  1488326400   [34, 17]
# 159       NaN  1491004800   [57, 32]
# 160       NaN  1493596800   [62, 10]
# 161       NaN  1496275200    [72, 8]
# 162       NaN  1498867200    [23, 9]
# 163       NaN  1501545600   [14, 29]
# 164       NaN  1504224000   [15, 79]
# 165       NaN  1506816000   [30, 79]
# 166       NaN  1509494400   [38, 68]
# 167       NaN  1512086400   [38, 80]
# 168       NaN  1514764800   [41, 78]
# 169       NaN  1517443200   [44, 19]
# 170       NaN  1519862400   [39, 19]
# 171       NaN  1522540800   [73, 34]
# 172       NaN  1525132800   [90, 10]
# 173       NaN  1527811200    [58, 8]
# 174       NaN  1530403200   [24, 10]
# 175       NaN  1533081600   [12, 31]
# 176       NaN  1535760000   [13, 89]
# 177       NaN  1538352000   [33, 79]
# 178       NaN  1541030400   [42, 78]
# 179       NaN  1543622400  [43, 100]
# 180       NaN  1546300800   [44, 90]
# 181       NaN  1548979200   [47, 20]
# 182       NaN  1551398400   [42, 19]
# 183       NaN  1554076800   [70, 32]
# 184       NaN  1556668800    [87, 8]
# 185       NaN  1559347200    [71, 7]
# 186       NaN  1561939200   [25, 10]
# 187      True  1564617600   [12, 31]
#
# [188 rows x 8 columns]

# %% [markdown]
# ----------
# now we unpack and plot the data
#
# ----------

# %%
import json # we use the json module to parse the json string.
import matplotlib.pyplot as plt
import datetime # datetime module is used to handle time information in python
# %matplotlib inline
plt.style.use('ggplot')
data = json.loads(response.text.split(',',1)[1].strip())
t,y,y1 = zip(*[(i['time'],i['value'][0],i['value'][1]) for i in data['default']['timelineData']])
t = [datetime.datetime.fromtimestamp(int(i)) for i in t]
plt.figure(figsize=(15,5))
plt.plot(t,y,label='NBA')
plt.plot(t,y1,label='NFL')
plt.legend()
plt.title('US Search Activity')
plt.ylabel('google trends')
# Out:
# Text(0, 0.5, 'google trends')

# %% [markdown]
# ** In-class exercise 1**
# * Click on the following link (https://coinmarketcap.com/currencies/bitcoin/#charts)
# * open the **>Network Monitor<** of your browser (refresh the page) and figure which request is collecting the data behind the chart.
# * Collect the data using requests.
# * Plot the "price_usd" data against time. Data comes as a nested dictionary.
#     * First you need to unpack this.
#     * Each datapoint is a [unix timestamp](https://en.wikipedia.org/wiki/Unix_time) in miliseconds and a price.
#     * To plot against time in python, you need to convert it to a datetime object using the ``datetime`` module.
#
# ``t = datetime.datetime.fromtimestamp(unixtime_in_seconds)``

# %%
# solution goes here

# %% [markdown]
# ## Navigating websites to collect links
# Now I will show you a few common ways of finding the links to the pages you want to scrape.

# %% [markdown]
# ### Building URLS using a recognizable pattern.
# A nice trick is to understand how urls are constructed to communicate with a server.
#
# Lets look at how [jobindex.dk](https://www.jobindex.dk/) does it. We simply click around and take note at how the addressline changes.
#
# This will allow us to navigate the page, without having to parse information from the html or click any buttons.
#
# * / is like folders on your computer.
# * ? entails the start of a query with parameters
# * = defines a variable: e.g. page=1000 or offset = 100 or showNumber=20
# * & separates different parameters.
# * \+ is html for whitespace

# %% [markdown]
# ### ** collecting unstructured data **
# Step 1. **Mapping** - Finding the pages to collect.
#
# Often times we need to crawl a set of pages, from a website, this means finding all the links we need to collect.
# Here is a simple example of doing that.
#
# Say we wanted to investigate the difference in how many hours of lectures and exercises the students on different universities and different study programs gets - if the ressources to exercises have been cut over the years, and whether this might affect dropout. To answer this question we decide to scrape the Course description of the university webpages.
#
# > First we look at the courses on UCPH:
# * Click on this link: https://kurser.ku.dk
# * Navigate to a page where links to courses are displayed.
# * Figure out a way to fetch those links.
# Here we look for the **"a"**-tag and the **"href"** attribute.
#
# Use your browsers **>Inspector<** to see the raw html that we want to parse.

# %%
# here I have found a list of courses at Anthropology UCPH
url = 'https://kurser.ku.dk/archive/2016-2017/STUDYBOARD_0010'
response = connector.get(url,'course_mapping')

# %%
#response.text

# %% [markdown]
# --------------
# After inspecting the html using our browsers Inspector tool, we can see that links occur after a href= pattern.
# Employing the python you already know we can use the ``string.split`` method to fetch the links.
# ______________

# %%
# we split by the pattern 'href="' and
# skip the first element that was before the first occurrece of href
link_locations = response.text.split('href="')[1:] 
###

links = [] #define container for the links
import random # good practice is to shuffle our data to inspect different data points each time.
# we do this with the random.sample function.
for link in random.sample(link_locations,len(link_locations)):
    #print(link)
    link = link.split('"')[0]
    links.append(link)
links[0:2]

# %%
# links are relative to the domain: https://kurser.ku.dk/
links = ['https://kurser.ku.dk'+ i for i in links]
print(len(links))
# only links with /archive/ in the name is a relevant course
links = [link for link in links if '/archive/' in link]
print(len(links))

# %%
print(random.sample(links,5))

# %% [markdown]
# ** In-class exercise 2** Now it your turn to practice collecting links using the simple split method.
#
# The above example only collected links to courses in Anthropology. Now I want you to build a script that
# * first collects links to all the different studyboards here: https://kurser.ku.dk/archive/2016-2017
#
# * And next run through those to collect the links to all the courses at UCPH 2016-2017.
#
# * figure out how to get links from the other years (hint look at the urls).

# %%
# solution goes here

# %% [markdown]
# ## Good practices
# * Transparency: send your email and name in the header so webmasters will know you are not a malicious actor.
# * Ratelimiting: Make sure you don't hit their servers to hard.
# * Reliability:
#     * Make sure the scraper can handle exceptions (e.g. bad connection) without crashing.
#     * Keep a log.
#     * Store raw data.

# %%
# Transparent scraping
import requests
#response = requests.get('https://www.google.com')
session = requests.session()
session.headers['email'] = 'youremail' 
session.headers['name'] = 'name'
#session.headers['User-Agent'] = '' # sometimes you need to pose as another agent...
session.headers

# %% [markdown]
# A quick tip is that you can change the user agent to a cellphone to obtain more simple formatting of the html.

# %% [markdown]
# # Reliability!
# When using found data, you are the curator and you are **responsible** for enscribing **trust** in the datacompilation.
#
# Reliability is ensured by an interative process, of inspection (many + randomly sampled), error detection and error handling.
#
# Build your scrape around making this process easy by:
# * logging information about the collection (e.g. servertime, size of response to plot weird behavior, size of response over time,  number of calls pr day, detection of holes in your data).
# * Storing raw data (before parsing it) to be able to backtrack problems, without having to wait for the error to come up.
