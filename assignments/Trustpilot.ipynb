# %% [markdown]
# # Trustpilot.com

# %%
import scraping_class

logfile="trustpilot.txt"
Connector = scraping_class.Connector(logfile)

# %% [markdown]
# <br>

# %%
import requests,os,time

def ratelimit():
    "A function that handles the rate of your calls."
    time.sleep(1) # sleep one second.

class Connector():
  def __init__(self,logfile,overwrite_log=False,connector_type='requests',session=False,path2selenium='',n_tries = 5,timeout=30):
    """This Class implements a method for reliable connection to the internet and monitoring. 
    It handles simple errors due to connection problems, and logs a range of information for basic quality assessments
    
    Keyword arguments:
    logfile -- path to the logfile
    overwrite_log -- bool, defining if logfile should be cleared (rarely the case). 
    connector_type -- use the 'requests' module or the 'selenium'. Will have different since the selenium webdriver does not have a similar response object when using the get method, and monitoring the behavior cannot be automated in the same way.
    session -- requests.session object. For defining custom headers and proxies.
    path2selenium -- str, sets the path to the geckodriver needed when using selenium.
    n_tries -- int, defines the number of retries the *get* method will try to avoid random connection errors.
    timeout -- int, seconds the get request will wait for the server to respond, again to avoid connection errors.
    """
    
    ## Initialization function defining parameters. 
    self.n_tries = n_tries # For avoiding triviel error e.g. connection errors, this defines how many times it will retry.
    self.timeout = timeout # Defining the maximum time to wait for a server to response.
    ## not implemented here, if you use selenium.
    if connector_type=='selenium':
      assert path2selenium!='', "You need to specify the path to you geckodriver if you want to use Selenium"
      from selenium import webdriver 
      ## HIN download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases

      assert os.path.isfile(path2selenium),'You need to insert a valid path2selenium the path to your geckodriver. You can download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases'
      self.browser = webdriver.Firefox(executable_path=path2selenium) # start the browser with a path to the geckodriver.

    self.connector_type = connector_type # set the connector_type
    
    if session: # set the custom session
      self.session = session
    else:
      self.session = requests.session()
    self.logfilename = logfile # set the logfile path
    ## define header for the logfile
    header = ['id','project','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
    if os.path.isfile(logfile):        
      if overwrite_log==True:
        self.log = open(logfile,'w')
        self.log.write(';'.join(header))
      else:
        self.log = open(logfile,'a')
    else:
      self.log = open(logfile,'w')
      self.log.write(';'.join(header))
    ## load log 
    with open(logfile,'r') as f: # open file
        
      l = f.read().split('\n') # read and split file by newlines.
      ## set id
      if len(l)<=1:
        self.id = 0
      else:
        self.id = int(l[-1][0])+1
            
  def get(self,url,project_name):
    """Method for connector reliably to the internet, with multiple tries and simple error handling, as well as default logging function.
    Input url and the project name for the log (i.e. is it part of mapping the domain, or is it the part of the final stage in the data collection).
    
    Keyword arguments:
    url -- str, url
    project_name -- str, Name used for analyzing the log. Use case could be the 'Mapping of domain','Meta_data_collection','main data collection'. 
    """
     
    project_name = project_name.replace(';','-') # make sure the default csv seperator is not in the project_name.
    if self.connector_type=='requests': # Determine connector method.
      for _ in range(self.n_tries): # for loop defining number of retries with the requests method.
        ratelimit()
        t = time.time()
        try: # error handling 
          response = self.session.get(url,timeout = self.timeout) # make get call

          err = '' # define python error variable as empty assumming success.
          success = True # define success variable
          redirect_url = response.url # log current url, after potential redirects 
          dt = t - time.time() # define delta-time waiting for the server and downloading content.
          size = len(response.text) # define variable for size of html content of the response.
          response_code = response.status_code # log status code.
          ## log...
          call_id = self.id # get current unique identifier for the call
          self.id+=1 # increment call id
          #['id','project_name','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row to be written in the log.
          self.log.write('\n'+';'.join(map(str,row))) # write log.
          return response,call_id # return response and unique identifier.

        except Exception as e: # define error condition
          err = str(e) # python error
          response_code = '' # blank response code 
          success = False # call success = False
          size = 0 # content is empty.
          redirect_url = '' # redirect url empty 
          dt = t - time.time() # define delta t

          ## log...
          call_id = self.id # define unique identifier
          self.id+=1 # increment call_id

          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row
          self.log.write('\n'+';'.join(map(str,row))) # write row to log.
    else:
      t = time.time()
      ratelimit()
      self.browser.get(url) # use selenium get method
      ## log
      call_id = self.id # define unique identifier for the call. 
      self.id+=1 # increment the call_id
      err = '' # blank error message
      success = '' # success blank
      redirect_url = self.browser.current_url # redirect url.
      dt = t - time.time() # get time for get method ... NOTE: not necessarily the complete load time.
      size = len(self.browser.page_source) # get size of content ... NOTE: not necessarily correct, since selenium works in the background, and could still be loading.
      response_code = '' # empty response code.
      row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row 
      self.log.write('\n'+';'.join(map(str,row))) # write row to log file.
    # Using selenium it will not return a response object, instead you should call the browser object of the connector.
    ## connector.browser.page_source will give you the html.
      return call_id
    

logfile="trustpilot.txt" ## name your log file.
connector = Connector(logfile)

# %% [markdown]
# <br>

# %%
url = 'https://www.trustpilot.com/review/59f33de00000ff0005aed171/jsonld'
response,call_id = connector.get(url,'art')

if response.ok:
    html = response.text
else:
    print('error')
    
response.json()
# Out:
# [{'@context': 'http://schema.org',
#   '@id': 'https://www.trustpilot.com/review/www.logoorbit.com',
#   '@type': 'LocalBusiness',
#   'address': {'@type': 'PostalAddress',
#    'addressCountry': 'US',
#    'addressLocality': 'New York',
#    'postalCode': '10001',
#    'streetAddress': '5th Avenue 244'},
#   'aggregateRating': {'@type': 'AggregateRating',
#    'bestRating': '10',
#    'ratingValue': '9.8',
#    'reviewCount': '154',
#    'worstRating': '0'},
#   'email': 'support@logoorbit.com',
#   'image': 'https://s3-eu-west-1.amazonaws.com/tpd/screenshotlogo-domain/59f33de00000ff0005aed171/198x149.png',
#   'name': 'Logo Orbit',
#   'review': [{'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Ariaan Cardenas',
#      'url': 'https://www.trustpilot.com/users/5d5af4aef2df44ddb7acbe54'},
#     'datePublished': '2019-08-19T19:12:48Z',
#     'headline': 'Working with Logo Orbut was great',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Working with Logo Orbut was great! This is my first time with them and my first business. They helped me in many different ways. Giving me suggestions, tips, and much more. They work quickly and deliver quality work. I would definitely recommend them to anyone looking for an amazing logo!',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d2c76c1a4257a54cf9bf50d/73x73.png',
#      'name': 'Aaron McCann',
#      'url': 'https://www.trustpilot.com/users/5d2c76c1a4257a54cf9bf50d'},
#     'datePublished': '2019-08-10T04:59:37Z',
#     'headline': 'Check out my logo ColorMend.com',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'I Love my Logo.  Jack did a great job! I encourage you to see what Jack created for me at ColorMend.com.  He was very professional, and the service was great. I hope I have just as good as an experience with the website that is underway.  I am currently working with Robert Jones on the website. I will let you guys know how that went when it is finished. I purchased the Ultimate package.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Rich',
#      'url': 'https://www.trustpilot.com/users/5d48d76a6badfacf40d037bb'},
#     'datePublished': '2019-08-06T01:27:08Z',
#     'headline': 'Second time was as good as the first',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'This is the second time I have used Sam and his team at logo orbit, and once again, they provided timely, efficient service and a product that was precisely what I was looking for.  I agree with the earlier comments made about getting the premium package with unlimited revisions. The team worked with me to achieve the perfect design for my product. When I need help in the future, I will definitely use logo orbit again.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d43886c39d16b2f7f980b59/73x73.png',
#      'name': 'B&B Lawn Maintenance',
#      'url': 'https://www.trustpilot.com/users/5d43886c39d16b2f7f980b59'},
#     'datePublished': '2019-08-02T00:49:32Z',
#     'headline': 'T-shirts came out great',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'The free business cards were not legible. Other than that I still give 5 stars because they were able to nail my logo on the head after 2 or 3 designs. Sam has been very helpful with any changes I have needed to perfect my logo. I also ordered 15 t-shirts for my business that I am very happy with. I will definitely be ordering more shirts in the near future. Thanks Sam!',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d40734daf37c4a91e4f2263/73x73.png',
#      'name': 'Simon McDermott',
#      'url': 'https://www.trustpilot.com/users/5d40734daf37c4a91e4f2263'},
#     'datePublished': '2019-07-30T16:41:57Z',
#     'headline': 'Sam Marcus and his team were awesome!',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': "Sam Marcus and his team were awesome!! I was skeptical about using them at first, but they really came through. I asked the team to design two logos and two business cards for me, and I LOVE what they came up with. One tip...pay for the premium service where you get unlimited revisions, It's so worth it. Once the design starts to take shape, you can really drill down and get exactly what you want. Revisions were always turned around for me in 24 hours or less. I would use these guys again in a heartbeat!",
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d38a1767576c4bddd28d2e7/73x73.png',
#      'name': 'jwls rico',
#      'url': 'https://www.trustpilot.com/users/5d38a1767576c4bddd28d2e7'},
#     'datePublished': '2019-07-24T18:20:48Z',
#     'headline': 'I highly recommend this group',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'I highly recommend this group. The design team is amazing! Customer service is great. They are patient and efficient. They work with you until you are happy with your project. Give them a shot you won’t regret! Jack and Riz are a pleasure to work with ask for them by name.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d365a1f89ce867d85e6810a/73x73.png',
#      'name': 'Big Palmy Muscle',
#      'url': 'https://www.trustpilot.com/users/5d365a1f89ce867d85e6810a'},
#     'datePublished': '2019-07-23T00:51:51Z',
#     'headline': 'In creation of my website…',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'In creation of my website BigPalmyMuscle.com, Robert Jones, Logo Orbit Key Account Manager, handled all requests and made the process stress free all while developing a flawless website to my exact specifications.\n\nThank you Robert',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Dave Page',
#      'url': 'https://www.trustpilot.com/users/5d322a37a3e2380c512a4055'},
#     'datePublished': '2019-07-19T20:38:16Z',
#     'headline': 'Great customer buying experience…',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Great customer buying experience provided by Neil J Thompson, I highly recommend.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Loretta Tuttle',
#      'url': 'https://www.trustpilot.com/users/5d2fe042919267cfdd52d04b'},
#     'datePublished': '2019-07-18T02:58:12Z',
#     'headline': 'Gratitude and great appreciation!',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'I absolutely could not have had a better experience or team to work with than Sam Marcus and his designers. Their patience, kindness and excellent customer service far exceeded my expectations. My hope is that their final design brings my clients the kind of joy that it brings me.  I will not hesitate to work with them on future projects.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d289038ee24f86d3f736c7d/73x73.png',
#      'name': 'Nasim tehrani',
#      'url': 'https://www.trustpilot.com/users/5d289038ee24f86d3f736c7d'},
#     'datePublished': '2019-07-12T13:51:31Z',
#     'headline': 'Great Job!!',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Great Job!!! Robert from Logo Orbit is great. He helped me with my logo design  in addition to website  services. They always contact you with new updates. Highly recommend them.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'image': 'https://user-images.trustpilot.com/5d27aa5ca4257a34b79a5740/73x73.png',
#      'name': 'Tommy Michael Caldwell',
#      'url': 'https://www.trustpilot.com/users/5d27aa5ca4257a34b79a5740'},
#     'datePublished': '2019-07-11T21:30:22Z',
#     'headline': 'Easy and Effective Logo Designs',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'I got logo services in addition to web design from Logo Orbit. My website is still being developed but the logo is finished. Logo Orbit worked with me, created all my revisions, and responded quickly. Was a simple and productive experience working with them.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'carl winfrey',
#      'url': 'https://www.trustpilot.com/users/5d27742a52fcc404c616cf1e'},
#     'datePublished': '2019-07-11T17:39:07Z',
#     'headline': 'I have a friend who promised to design…',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'I have a friend who promised to design a logo for our newly formed business. As he reneged, I went on line in search of a logo company. I clicked on Logoorbit and found myself in a live chat with Jack Brown. I wasn\'t sure if this was a legitimate company, but continued to give info as to what I wanted. I selected a price range, and Jack stated that the team would get right on it. He asked how much I would be putting down, and I thought: "Oh boy! Here we go!!!" I knew my pay day would  be coming in four days, and I communicated that to him. Jack said: "I tell you what. We will do the designs, and you can owe us." I consented to those terms. In less than 2-days, the team had put together some great designs.The work was professional and timely. This company is NOT a sham! If it\'s professionalism you want, Logoorbit is the place!',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Leslie',
#      'url': 'https://www.trustpilot.com/users/591d8c750000ff000a99b4d5'},
#     'datePublished': '2019-07-09T18:18:19Z',
#     'headline': 'Great job',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Great job! Attention to detail, care and consideration for exactly what I asked for... just a wonderful job well done!  Thank you Sam Marcus!',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Anthony Ciraulo',
#      'url': 'https://www.trustpilot.com/users/5d1ffc52b6ae9195bb2c6c00'},
#     'datePublished': '2019-07-06T01:46:22Z',
#     'headline': 'Exceeded expectations',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Exceeded expectations. Used to get logos for two different companies, and got them back fast and wonderful design. Could not be happier with the design team and Sam Marcus for keeping my updated every step of the way. I will use for any and all future design needs.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Nick Steele',
#      'url': 'https://www.trustpilot.com/users/5d16849897935f9b6dd66280'},
#     'datePublished': '2019-06-28T21:20:30Z',
#     'headline': 'They stuck with us giving us about 30+…',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'They stuck with us giving us about 30+ iterations. We finally settled on our own character design, but they converted it to a vector for us so expertly we actually thought it was the same bitmap at first. These guys/girls are great!',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Rob Miller',
#      'url': 'https://www.trustpilot.com/users/5d0e7369c67dec32dcef363d'},
#     'datePublished': '2019-06-22T18:29:11Z',
#     'headline': 'The Logo Orbit team really rocks!',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'The Logo Orbit team really rocks!!  Sam Marcus and the team came through when I needed super-fast turnaround and delivered exactly what I needed.  Nice job guys! \n-Rob M.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Ryan Greene',
#      'url': 'https://www.trustpilot.com/users/5d040b3df371c60f9692e14d'},
#     'datePublished': '2019-06-14T21:01:51Z',
#     'headline': 'Logo Orbit rocks!',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'I worked with Sam Marcus on this project. His replies were prompt, and always very thorough. Sam and his team were very easy to work with, and came up with a very quality logo for our podcast. I would easily recommend this service, and would happy use it again!',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Aaron Rauen',
#      'url': 'https://www.trustpilot.com/users/5cf1d7b50d0a0c0da4ba02a3'},
#     'datePublished': '2019-06-01T01:41:18Z',
#     'headline': 'Robert did a great job helping with my…',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Robert did a great job helping with my project!  Very responsive and thorough.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Jordan & Karli Peterson',
#      'url': 'https://www.trustpilot.com/users/5cedbc20d0f7460b614f3096'},
#     'datePublished': '2019-05-28T22:54:40Z',
#     'headline': 'Great experience',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': 'Great experience. User friendly. Sam, our project manager, was very helpful and accomodating. I highly recommend this service.',
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}},
#    {'@type': 'Review',
#     'author': {'@type': 'Person',
#      'name': 'Mark Walstrom',
#      'url': 'https://www.trustpilot.com/users/5ce45385ddb8fd690d044d54'},
#     'datePublished': '2019-05-21T19:37:43Z',
#     'headline': 'I just want to say that Robert was a…',
#     'inLanguage': 'en',
#     'itemReviewed': {'@type': 'Thing', 'name': 'Logo Orbit'},
#     'publisher': {'@type': 'Organization',
#      'name': 'Trustpilot',
#      'sameAs': 'https://www.trustpilot.com'},
#     'reviewBody': "I just want to say that Robert was a pleasure to work with.  The entire staff was great!  These guys are very good at what they do! The provide excellent customer service and walked me through every step of the process.  I would highly recommend them to anyone. I'm happy with my decision to hire them to develop my website and creating my company logo.",
#     'reviewRating': {'@type': 'Rating',
#      'bestRating': '5',
#      'ratingValue': '5',
#      'worstRating': '1'}}],
#   'telephone': '551-227-4523',
#   'url': 'http://www.logoorbit.com'},
#  {'@context': 'http://schema.org',
#   '@type': 'Dataset',
#   'description': 'Bar chart review and ratings distribution for Logo Orbit',
#   'mainEntity': {'@type': 'csvw:Table',
#    'csvw:tableSchema': {'csvw:columns': [{'csvw:cells': [{'csvw:notes': ['1%'],
#         'csvw:value': '1'}],
#       'csvw:datatype': 'integer',
#       'csvw:name': '1 star'},
#      {'csvw:cells': [{'csvw:notes': ['0%'], 'csvw:value': '0'}],
#       'csvw:datatype': 'integer',
#       'csvw:name': '2 stars'},
#      {'csvw:cells': [{'csvw:notes': ['1%'], 'csvw:value': '1'}],
#       'csvw:datatype': 'integer',
#       'csvw:name': '3 stars'},
#      {'csvw:cells': [{'csvw:notes': ['1%'], 'csvw:value': '1'}],
#       'csvw:datatype': 'integer',
#       'csvw:name': '4 stars'},
#      {'csvw:cells': [{'csvw:notes': ['98%'], 'csvw:value': '151'}],
#       'csvw:datatype': 'integer',
#       'csvw:name': '5 stars'},
#      {'csvw:cells': [{'csvw:notes': ['100%'], 'csvw:value': '154'}],
#       'csvw:datatype': 'integer',
#       'csvw:name': 'Total'}]}},
#   'name': 'Logo Orbit',
#   'publisher': {'@type': 'Organization',
#    'name': 'Trustpilot',
#    'sameAs': 'https://www.trustpilot.com'}}]
